# %%
import json
import random
from collections import namedtuple

import pandas as pd
import numpy as np
import scipy.stats as ss

import matplotlib.pyplot as plt

# %matplotlib inline

np.random.seed(42)

# %%
data = pd.read_json("/Users/aleksandr/Desktop/recsys_made2023/botify_recsys/log/experiments/top_pop/data.json", lines=True)
data["rnd"] = np.random.random(len(data))

data.head(20)
# Out:
#    message               timestamp  user  track  time   latency  \
# 0     next 2023-03-29 19:34:45.843   404   1084  1.00  0.006241
# 1     next 2023-03-29 19:34:45.851   404   1084  1.00  0.000302
# 2     next 2023-03-29 19:34:45.854   404   1084  1.00  0.001366
# 3     next 2023-03-29 19:34:45.856   404   1084  1.00  0.000624
# 4     next 2023-03-29 19:34:45.865   404    487  0.00  0.000453
# 5     next 2023-03-29 19:34:45.866   404   8693  0.00  0.000288
# 6     next 2023-03-29 19:34:45.867   404   2016  0.00  0.000241
# 7     next 2023-03-29 19:34:45.868   404  43262  0.00  0.000327
# 8     next 2023-03-29 19:34:45.883   404   2205  0.00  0.000647
# 9     next 2023-03-29 19:34:45.885   404   8381  0.00  0.000447
# 10    next 2023-03-29 19:34:45.886   404   8012  0.00  0.000273
# 11    next 2023-03-29 19:34:45.886   404  37241  0.00  0.000427
# 12    next 2023-03-29 19:34:45.891   404  37847  0.00  0.000422
# 13    next 2023-03-29 19:34:45.894   404   4373  0.00  0.000350
# 14    next 2023-03-29 19:34:45.895   404  27795  0.00  0.000410
# 15    next 2023-03-29 19:34:45.896   404  22874  0.00  0.000417
# 16    next 2023-03-29 19:34:45.898   404  11869  0.00  0.000398
# 17    next 2023-03-29 19:34:45.913   404  32361  0.05  0.000361
# 18    next 2023-03-29 19:34:45.914   404  22833  0.00  0.000233
# 19    next 2023-03-29 19:34:45.915   404  21861  0.00  0.000505
#
#     recommendation             experiments       rnd
# 0           8693.0  {'STICKY_ARTIST': 'C'}  0.031057
# 1            487.0  {'STICKY_ARTIST': 'C'}  0.554181
# 2          43262.0  {'STICKY_ARTIST': 'C'}  0.762033
# 3           2016.0  {'STICKY_ARTIST': 'C'}  0.537379
# 4           8381.0  {'STICKY_ARTIST': 'C'}  0.840785
# 5           2205.0  {'STICKY_ARTIST': 'C'}  0.033427
# 6           8012.0  {'STICKY_ARTIST': 'C'}  0.366752
# 7          37241.0  {'STICKY_ARTIST': 'C'}  0.237070
# 8          37847.0  {'STICKY_ARTIST': 'C'}  0.447273
# 9          22874.0  {'STICKY_ARTIST': 'C'}  0.072376
# 10          4373.0  {'STICKY_ARTIST': 'C'}  0.954132
# 11         27795.0  {'STICKY_ARTIST': 'C'}  0.223255
# 12         11869.0  {'STICKY_ARTIST': 'C'}  0.922308
# 13         22833.0  {'STICKY_ARTIST': 'C'}  0.425893
# 14         32361.0  {'STICKY_ARTIST': 'C'}  0.985524
# 15         21861.0  {'STICKY_ARTIST': 'C'}  0.554058
# 16         46098.0  {'STICKY_ARTIST': 'C'}  0.930833
# 17         16703.0  {'STICKY_ARTIST': 'C'}  0.005349
# 18         45307.0  {'STICKY_ARTIST': 'C'}  0.748239
# 19         19346.0  {'STICKY_ARTIST': 'C'}  0.903051

# %% [markdown]
# ## Compute track popularity

# %%
track_popularity = (
    data[data["rnd"] > 0.5]
    .groupby("track")["time"]
    .sum()
    .to_frame()
    .sort_values("time", ascending=False)
    .reset_index()
)

track_popularity.head()
# Out:
#    track   time
# 0   4205  57.97
# 1    246  50.39
# 2    171  49.47
# 3    176  49.00
# 4    177  46.54

# %%
len(track_popularity)
# Out:
# 45687

# %%
fig, ax = plt.subplots(figsize=(20, 5))

ax.plot(track_popularity.index.values, track_popularity["time"].values)

# ax.set_xscale("log")
# ax.set_yscale("log")

pass

# %% [markdown]
# ## Compute offline metrics

# %%
# recommendations - список рекомендованных track id от лучшего к худшему
# track           - id трека, который выбрал пользователь
# k               - k в precision@K


def precision_at(recommendations, track, k):
    return 1.0 / k * int(track in recommendations[:k])


    
def shuffled_precision_at(recommendations, track, k):
    shuffled = list(recommendations)
    random.shuffle(shuffled)
    return precision_at(shuffled, track, k)

# %%
tracks = track_popularity["track"].tolist()

t_p_10 = lambda track: precision_at(tracks, track, 10)
st_10_p_10 = lambda track: shuffled_precision_at(tracks[:10], track, 10)
st_100_p_10 = lambda track: shuffled_precision_at(tracks[:100], track, 10)
st_1000_p_10 = lambda track: shuffled_precision_at(tracks[:1000], track, 10)


metrics = data[(data["rnd"] <= 0.5) & (data["time"] >= 0.75)].copy()

metrics["top10_PrecAt10"] = metrics["track"].map(t_p_10)
metrics["shuffledTop10_PrecAt10"] = metrics["track"].map(st_10_p_10)
metrics["shuffledTop100_PrecAt10"] = metrics["track"].map(st_100_p_10)
metrics["shuffledTop1000_PrecAt10"] = metrics["track"].map(st_1000_p_10)

metrics[["top10_PrecAt10", "shuffledTop10_PrecAt10", "shuffledTop100_PrecAt10", "shuffledTop1000_PrecAt10"]].describe()
# Out:
#        top10_PrecAt10  shuffledTop10_PrecAt10  shuffledTop100_PrecAt10  \
# count    33424.000000            33424.000000             33424.000000
# mean         0.001278                0.001278                 0.000571
# std          0.011231                0.011231                 0.007538
# min          0.000000                0.000000                 0.000000
# 25%          0.000000                0.000000                 0.000000
# 50%          0.000000                0.000000                 0.000000
# 75%          0.000000                0.000000                 0.000000
# max          0.100000                0.100000                 0.100000
#
#        shuffledTop1000_PrecAt10
# count              33424.000000
# mean                   0.000194
# std                    0.004406
# min                    0.000000
# 25%                    0.000000
# 50%                    0.000000
# 75%                    0.000000
# max                    0.100000

# %%
def mrr(recommendations, track):
    return 1.0 / (1 + recommendations.index(track)) if track in recommendations else 0.0

    
def shuffled_mrr(recommendations, track):
    shuffled = list(recommendations)
    random.shuffle(shuffled)
    return mrr(shuffled, track)

# %%
tracks = track_popularity["track"].tolist()

t_mrr = lambda track: mrr(tracks, track)
st_10_mrr = lambda track: shuffled_mrr(tracks[:10], track)
st_100_mrr = lambda track: shuffled_mrr(tracks[:100], track)
st_1000_mrr = lambda track: shuffled_mrr(tracks[:1000], track)

metrics = data[(data["rnd"] <= 0.5) & (data["time"] >= 0.75)].copy()

metrics["top10_mrr"] = metrics["track"].map(t_mrr)
metrics["shuffledTop10_mrr"] = metrics["track"].map(st_10_mrr)
metrics["shuffledTop100_mrr"] = metrics["track"].map(st_100_mrr)
metrics["shuffledTop1000_mrr"] = metrics["track"].map(st_1000_mrr)

metrics[["top10_mrr", "shuffledTop10_mrr", "shuffledTop100_mrr", "shuffledTop1000_mrr"]].describe()
# Out:
#           top10_mrr  shuffledTop10_mrr  shuffledTop100_mrr  \
# count  33424.000000       33424.000000        33424.000000
# mean       0.005871           0.003824            0.002908
# std        0.046686           0.045684            0.029934
# min        0.000000           0.000000            0.000000
# 25%        0.000039           0.000000            0.000000
# 50%        0.000122           0.000000            0.000000
# 75%        0.000681           0.000000            0.000000
# max        1.000000           1.000000            1.000000
#
#        shuffledTop1000_mrr
# count         33424.000000
# mean              0.001531
# std               0.019626
# min               0.000000
# 25%               0.000000
# 50%               0.000000
# 75%               0.000000
# max               1.000000

# %% [markdown]
# ## Export data for prod

# %%
with open("/Users/aleksandr/Desktop/recsys_made2023/botify_recsys/data/top_tracks.json", "w") as top_tracks_file:
    json.dump(track_popularity["track"].tolist(), top_tracks_file)
